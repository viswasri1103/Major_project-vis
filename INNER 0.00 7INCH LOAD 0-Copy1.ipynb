# %%
import numpy as np
import pandas as pd
import matplotlib as mb
import seaborn as sns
import scipy.stats 
import requests
# %matplotlib inline

# %%
def find_df(path,ftype,label,label_no):
    data=pd.read_csv(path,header=None) 
    df_bearing=np.array(data.iloc[:,0])
   
    temp=df_bearing
    temp

    i=0
    initial_data=[]
    for i in range(0,len(temp),1670):
        initial_data.append(temp[i:i+1670])


    split=[]
    for i in initial_data:
        split.append(i[35:-35])


    mean=[]
    maximum=[]
    minimum=[]
    Variance=[]
    Range=[]
    Standard_deviation=[]
    Absolute_mean=[]
    ABSMAX=[]
    sqr=[]
    RMS=[] 
    Kurtosis=[]
    Skewness=[]
    clearance_factor=[]
    ABSV=[]

    for i in range(len(split)):
        temp_mean= np.mean(split[i])
        mean.append(temp_mean)
    #MAXIMUM
        temp_maximum= np.max(split[i])
        maximum.append(temp_maximum)
    #MINIMUM    
        temp_minimum= np.min(split[i])
        minimum.append(temp_minimum)
    #RANGE
        temp_range= np.max(split[i])- np.min(split[i])
        Range.append(temp_range)
    #STANDARD DEVIATION
        temp_std= np.std(split[i])
        Standard_deviation.append(temp_std)
    #VARIANCE
        temp_vrc= np.var(split[i])
        Variance.append(temp_vrc)
    #ABSOLUTE MEAN
        temp_abs= (np.sum(np.absolute(split[i]))/len(split[i]))
        Absolute_mean.append(temp_abs)
    #SQUARES
        temp_sqr= (np.square(split[i]))
        sqr.append(temp_sqr)
    #RMS
        temp_rms= np.sqrt(np.mean(sqr[i]))
        RMS.append(temp_rms)
    #ABSOLUTE MAXIMUM    
        temp_absmax= np.max(np.absolute(split[i]))
        ABSMAX.append(temp_absmax)
    #KURTOSIS
        temp_kur=scipy.stats.kurtosis(split[i], fisher=True)
        Kurtosis.append(temp_kur)
    #SKEWNESS
        temp_skw=scipy.stats.skew(split[i])
        Skewness.append(temp_skw)
    #ABSOLUTE VALUES  
        temp_absv=np.absolute(split[i])
        ABSV.append(temp_absv)




    for i in range(len(split)):
        #CIF
        temp_cif=ABSMAX[i]/(np.square(np.mean(np.sqrt(ABSV[i]))))
        clearance_factor.append(temp_cif)
    #clearance_factor    

    FINAL_DATA=pd.DataFrame(data=mean)
    FINAL_DATA

    headers=['Mean']
    FINAL_DATA.columns=headers
    FINAL_DATA['Maximum_value']= maximum
    FINAL_DATA['Minimum_value']= minimum
    FINAL_DATA['Range']= Range
    FINAL_DATA['Standard Deviation']=Standard_deviation
    FINAL_DATA['Variance']=Variance
    FINAL_DATA['Absolute_mean']=Absolute_mean
    FINAL_DATA['Absolute_MAX']=ABSMAX
    FINAL_DATA['RMS']=RMS
    FINAL_DATA['Crest Factor']=FINAL_DATA['Absolute_MAX']/FINAL_DATA['RMS']
    FINAL_DATA['Shape factor']=FINAL_DATA['RMS']/FINAL_DATA['Absolute_mean']
    FINAL_DATA['Impulse Factor']=FINAL_DATA['Absolute_MAX']/FINAL_DATA['Absolute_mean']
    FINAL_DATA['Kurtosis']=Kurtosis
    FINAL_DATA['Skewness']=Skewness
    FINAL_DATA['Clearance Factor']=clearance_factor
    FINAL_DATA['FAULT TYPE']=ftype
    FINAL_DATA['Label']=label  
    FINAL_DATA['Label_no']=label_no
    return FINAL_DATA

# %%
paths_url='/Users/srinivasaadvaith/Desktop/FINAL CODES/DATA/urls/LOAD 0 URLS.csv'
paths=pd.read_csv(paths_url,header=None)
headers=['links','Fault type','Label']
paths.columns=headers
p=find_df(paths['links'][0],paths['Fault type'][0],paths['Label'][0],0)
for i in range(1,10): 
    s=find_df(paths['links'][i],paths['Fault type'][i],paths['Label'][i],i) 
    p=pd.concat([p,s],ignore_index=True)

p.to_csv('DATA_0.csv')


#paths

# %%
p.head()
# Out:
#        Mean  Maximum_value  Minimum_value     Range  Standard Deviation  \
# 0  0.083829       2.826181      -2.236072  5.062253            0.573852
# 1  0.086462       2.716423      -2.591640  5.308063            0.602879
# 2  0.076461       2.498157      -2.565765  5.063923            0.572858
# 3  0.090060       2.836197      -2.148849  4.985047            0.591450
# 4  0.083227       2.575364      -2.432219  5.007583            0.557509
#
#    Variance  Absolute_mean  Absolute_MAX       RMS  Crest Factor  \
# 0  0.329306       0.421070      2.826181  0.579942      4.873211
# 1  0.363463       0.434774      2.716423  0.609047      4.460118
# 2  0.328166       0.412407      2.565765  0.577938      4.439516
# 3  0.349813       0.429457      2.836197  0.598267      4.740685
# 4  0.310817       0.401714      2.575364  0.563687      4.568782
#
#    Shape factor  Impulse Factor  Kurtosis  Skewness  Clearance Factor  \
# 0      1.377307        6.711907  2.807486 -0.001980          8.273841
# 1      1.400836        6.247893  2.897447 -0.035843          7.795792
# 2      1.401377        6.221436  2.853936 -0.099081          7.776081
# 3      1.393080        6.604153  2.730605  0.066273          8.253300
# 4      1.403205        6.410937  3.011029 -0.116492          7.987289
#
#                        FAULT TYPE   Label  Label_no
# 0  INNER RACE FAULT OF 0.007 INCH  IR_7_0         0
# 1  INNER RACE FAULT OF 0.007 INCH  IR_7_0         0
# 2  INNER RACE FAULT OF 0.007 INCH  IR_7_0         0
# 3  INNER RACE FAULT OF 0.007 INCH  IR_7_0         0
# 4  INNER RACE FAULT OF 0.007 INCH  IR_7_0         0
